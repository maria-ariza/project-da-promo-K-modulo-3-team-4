# %%
import pandas as pd

# %%
df = pd.read_csv('archivos/hr_raw_data_final.csv', index_col=[0])

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
# 3  47        No  travel_rarely  1771.404762                       NaN
# 4  46        No            NaN  1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        1       0         NaN
# ...

# %%
df.tail()
# Out:
#      age attrition businesstravel    dailyrate department  distancefromhome  \
# 1673  43        No            NaN   488.944444        NaN               -26
# 1674  47        No            NaN  1973.984127        NaN                26
# 1675  29        No  travel_rarely   290.035510        NaN                15
# 1676  47        No  travel_rarely  1032.487286        NaN                 4
# 1677  32        No            NaN   556.256661        NaN                 2
#
#       education educationfield  employeecount  employeenumber  \
# 1673          3        Medical              1             824
# 1674          4            NaN              1            1087
# 1675          3            NaN              1             528
# 1676          3  Life Sciences              1              76
# 1677          2  Life Sciences              1             401
#
#       environmentsatisfaction  gender  hourlyrate  jobinvolvement  joblevel  \
# ...

# %%
df.sample()
# Out:
#      age attrition     businesstravel   dailyrate department  \
# 1606  26        No  travel_frequently  443.031746     Sales
#
#       distancefromhome  education educationfield  employeecount  \
# 1606                 1          3        Medical              1
#
#       employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 1606            1607                        3       0         NaN
#
#       jobinvolvement  joblevel            jobrole  jobsatisfaction  \
# 1606               2         2   sAleS EXECUtIvE                 1
#
#      maritalstatus monthlyincome monthlyrate  numcompaniesworked over18  \
# 1606           NaN      3578,33$    9303,67$                   1      Y
#
#      overtime  percentsalaryhike performancerating  relationshipsatisfaction  \
# 1606      NaN                 12               3,0                         2
#
#      standardhours  stockoptionlevel totalworkingyears  trainingtimeslastyear  \
# ...

# %%
print(f'Num. filas: {df.shape[0]}')
print(f'Num. columnas: {df.shape[1]}')
# Out:
# Num. filas: 1678
# Num. columnas: 41

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'gender', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'roledepartament', 'numberchildren', 'remotework'],
#       dtype='object')

# %%
df.describe()
# Out:
#          dailyrate  distancefromhome    education  employeecount  \
# count  1678.000000       1678.000000  1678.000000         1678.0
# mean    668.079714          4.504172     2.932658            1.0
# std     470.787298         14.652066     1.024270            0.0
# min     104.103175        -49.000000     1.000000            1.0
# 25%     290.035510          2.000000     2.000000            1.0
# 50%     556.256661          5.000000     3.000000            1.0
# 75%     971.956349         11.000000     4.000000            1.0
# max    2063.388889         29.000000     5.000000            1.0
#
#        employeenumber  environmentsatisfaction       gender  hourlyrate  \
# count     1678.000000              1678.000000  1678.000000  411.000000
# mean       809.859952                 4.264005     0.398689   83.140768
# std        467.084867                 6.912695     0.489774   57.272101
# min          1.000000                 1.000000     0.000000   13.012897
# ...

# %%
df.describe(include = "object").T
# Out:
#                     count unique  \
# age                  1678     54
# attrition            1678      2
# businesstravel        877      3
# department            312      3
# educationfield        904      6
# jobrole              1678   1579
# maritalstatus        1003      5
# monthlyincome        1189    493
# monthlyrate          1678    673
# over18                740      1
# overtime              982      2
# performancerating    1478      2
# standardhours        1327      2
# totalworkingyears    1129     40
# worklifebalance      1564      4
# yearsincurrentrole     35     10
# sameasmonthlyincome  1189    493
# salary               1393    583
# roledepartament       312    301
# remotework           1678      5
#
#                                                                  top  freq
# age                                                               35    88
# attrition                                                         No  1406
# ...

# %%
cat_values = df.describe(include = "object")

# %%
for columna in cat_values:
    print(f'La columna {columna} tiene los siguientes valores únicos:')
    print(cat_values[columna].unique())
    print('--------------------------------------------------------------')
# Out:
# La columna age tiene los siguientes valores únicos:
# [1678 54 '35' 88]
# --------------------------------------------------------------
# La columna attrition tiene los siguientes valores únicos:
# [1678 2 'No' 1406]
# --------------------------------------------------------------
# La columna businesstravel tiene los siguientes valores únicos:
# [877 3 'travel_rarely' 616]
# --------------------------------------------------------------
# La columna department tiene los siguientes valores únicos:
# [312 3 ' Research & Development ' 203]
# --------------------------------------------------------------
# La columna educationfield tiene los siguientes valores únicos:
# [904 6 'Life Sciences' 367]
# --------------------------------------------------------------
# La columna jobrole tiene los siguientes valores únicos:
# [1678 1579 ' mANager ' 5]
# --------------------------------------------------------------
# La columna maritalstatus tiene los siguientes valores únicos:
# ...

# %%
df.isnull().sum()
# Out:
# age                            0
# attrition                      0
# businesstravel               801
# dailyrate                      0
# department                  1366
# distancefromhome               0
# education                      0
# educationfield               774
# employeecount                  0
# employeenumber                 0
# environmentsatisfaction        0
# gender                         0
# hourlyrate                  1267
# jobinvolvement                 0
# joblevel                       0
# jobrole                        0
# jobsatisfaction                0
# maritalstatus                675
# monthlyincome                489
# monthlyrate                    0
# numcompaniesworked             0
# over18                       938
# overtime                     696
# percentsalaryhike              0
# performancerating            200
# relationshipsatisfaction       0
# standardhours                351
# stockoptionlevel               0
# ...

# %%
df.duplicated().sum()
# Out:
# 64

# %%
df.duplicated(keep=False).sum()
# Out:
# 128

# %%
df[df.duplicated(keep=False)].sort_values('age')
# Out:
#               age attrition businesstravel    dailyrate  \
# 1369           18       Yes            NaN   290.035510
# 1661           18       Yes            NaN   290.035510
# 1620           21       Yes  travel_rarely   290.035510
# 1338           21       Yes  travel_rarely   290.035510
# 957            22        No            NaN   556.256661
# ...           ...       ...            ...          ...
# 1473           58       Yes  travel_rarely  1032.487286
# 852            59        No  travel_rarely   290.035510
# 1615           59        No  travel_rarely   290.035510
# 1662  twenty-four        No            NaN   277.952381
# 1325  twenty-four        No            NaN   277.952381
#
#                     department  distancefromhome  education educationfield  \
# 1369                       NaN                 8          1            NaN
# 1661                       NaN                 8          1            NaN
# ...

# %%
for columna in cat_values:
    print(df[columna].value_counts())

    print('********************\n***********************')
# Out:
# age
# 35              88
# 31              88
# 34              86
# 29              82
# 36              79
# 32              66
# 30              65
# 38              64
# 33              63
# 40              60
# 28              54
# 37              54
# 27              54
# 45              50
# 42              50
# 41              48
# 39              46
# 26              46
# 43              42
# 46              38
# 44              34
# 50              34
# 47              30
# 24              29
# 25              28
# 49              26
# 55              25
# 51              22
# 48              22
# 53              20
# 54              20
# 52              18
# 56              18
# 21              17
# 22              17
# 58              16
# 23              15
# 59              11
# 20              11
# 18               9
# 19               9
# 57               6
# 60               5
# thirty-two       2
# twenty-four      2
# thirty           1
# fifty-eight      1
# ...

# %%
df.describe()
# Out:
#          dailyrate  distancefromhome    education  employeecount  \
# count  1678.000000       1678.000000  1678.000000         1678.0
# mean    668.079714          4.504172     2.932658            1.0
# std     470.787298         14.652066     1.024270            0.0
# min     104.103175        -49.000000     1.000000            1.0
# 25%     290.035510          2.000000     2.000000            1.0
# 50%     556.256661          5.000000     3.000000            1.0
# 75%     971.956349         11.000000     4.000000            1.0
# max    2063.388889         29.000000     5.000000            1.0
#
#        employeenumber  environmentsatisfaction       gender  hourlyrate  \
# count     1678.000000              1678.000000  1678.000000  411.000000
# mean       809.859952                 4.264005     0.398689   83.140768
# std        467.084867                 6.912695     0.489774   57.272101
# min          1.000000                 1.000000     0.000000   13.012897
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1678 non-null   object
#  1   attrition                 1678 non-null   object
#  2   businesstravel            877 non-null    object
#  3   dailyrate                 1678 non-null   float64
#  4   department                312 non-null    object
#  5   distancefromhome          1678 non-null   int64
#  6   education                 1678 non-null   int64
#  7   educationfield            904 non-null    object
#  8   employeecount             1678 non-null   int64
#  9   employeenumber            1678 non-null   int64
#  10  environmentsatisfaction   1678 non-null   int64
#  11  gender                    1678 non-null   int64
#  12  hourlyrate                411 non-null    float64
#  13  jobinvolvement            1678 non-null   int64
# ...
